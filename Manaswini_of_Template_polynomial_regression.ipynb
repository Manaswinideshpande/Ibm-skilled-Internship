# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
df = pd.read_csv("/content/Corn_Yield.csv")

# %%
df.head()
# Out:
#    Fertilizer Used  Corn Yield
# 0             0.00       10.99
# 1             5.26       12.69
# 2            10.53       19.99
# 3            15.79       30.25
# 4            21.05       38.01

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree =2)
x_poly = poly_reg.fit_transform(x)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(x,y,color ='red')
plt.plot(x,lin_reg.predict(x),color='blue')
plt.title('Linear Regression')
plt.xlabel('Position Level')
plt.ylabel('Corn Yield')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
# Visualization
plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='red', label='Actual Data')

# Create a range of values for x to plot the polynomial curve
x_grid = np.linspace(min(x), max(x), 100).reshape(-1, 1)
x_grid_poly = poly_reg.transform(x_grid)
plt.plot(x_grid, lin_reg_2.predict(x_grid_poly), color='blue', label='Polynomial Regression')
plt.title('Polynomial Regression')
plt.xlabel('Position Level')
plt.ylabel('Corn Yield')
plt.legend()
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
new_position = np.array([[6]])  # Example new input for prediction
predicted_linear = lin_reg.predict(new_position)

# %%
predicted_linear
# Out:
# array([-35.82856317])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
new_position_poly = poly_reg.transform(new_position)
predicted_polynomial = lin_reg_2.predict(new_position_poly)

# %%
predicted_polynomial
# Out:
# array([14.78370988])
